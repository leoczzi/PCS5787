# %%
pd.set_option('display.float_format', lambda x: '%.7f' % x)

# %%
## PIB
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_pib_melted, x="Year", y="Pib", hue="Municípios", style = 'Municípios', ax = ax, markers = True)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

ax.ticklabel_format(style='plain', axis = 'y')
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
plt.xticks(rotation=45)
plt.ylabel('PIB')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - PIB por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_pib.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
top10_pib_melted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66faf0a084a8> in <module>()
# ----> 1 top10_pib_melted
#
# NameError: name 'top10_pib_melted' is not defined

# %%
## População
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_populacao_melted, x="Year", y="Populacao", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('População')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - População por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_populacao.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
## Assalariadas
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_assalariadas_melted, x="Year", y="Assalariadas", hue="Municípios", style = 'Municípios', ax = ax, markers = True) 

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Qtd. Pessoas Assalariadas')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Qtd. Pessoas Assalariadas por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_assalariadas.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
## Empregadas
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_empregadas_melted, x="Year", y="Empregadas", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Qtd. Pessoas Empregadas')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Qtd. Pessoas Empregadas por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_empregadas.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
## Empresas
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_empresas_melted , x="Year", y="Empresas", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Qtd. Empresas')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Unidades Empresariais por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_empresas.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
top10_salarios_melted
# Out:
#       Código           Municípios  Year          Salarios
# 0    3550308       São Paulo (SP)  2006 101784140.0000000
# 1    5300108        Brasília (DF)  2006  42179912.0000000
# 2    3304557  Rio de Janeiro (RJ)  2006  46111937.0000000
# 3    3106200  Belo Horizonte (MG)  2006  19567068.0000000
# 4    4106902        Curitiba (PR)  2006  12286533.0000000
# ..       ...                  ...   ...               ...
# 125  4314902    Porto Alegre (RS)  2018  36902415.0000000
# 126  2927408        Salvador (BA)  2018  29739222.0000000
# 127  2304400       Fortaleza (CE)  2018  26310075.0000000
# 128  2611606          Recife (PE)  2018  24520810.0000000
# 129  5208707         Goiânia (GO)  2018  22656133.0000000
#
# [130 rows x 4 columns]

# %%
## Salário
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_salarios_melted  , x="Year", y="Salarios", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Salário')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Salário por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_salarios.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
#df_salario_pessoas = salarios_melted.merge(assalariadas_melted['Assalariadas'], left_index = True, right_index = True, how = 'left')
#df_salario_pessoas['Salário Médio por Assalariado'] = df_salario_pessoas['Salarios'] / df_salario_pessoas['Assalariadas']

# %%
top10_salario_assalariado_melted
# Out:
#       Código           Municípios  Year   Salarios
# 0    5300108        Brasília (DF)  2006  33.199119
# 1    3135407         Jeceaba (MG)  2006   7.670498
# 2    2803708       Macambira (SE)  2006   5.213483
# 3    4309605     Horizontina (RS)  2006  19.569207
# 4    4205407   Florianópolis (SC)  2006  21.444174
# ..       ...                  ...   ...        ...
# 125  2905701        Camaçari (BA)  2018  58.382160
# 126  3304110      Porto Real (RJ)  2018  57.687909
# 127  5103403          Cuiabá (MT)  2018  54.804166
# 128  3304557  Rio de Janeiro (RJ)  2018  54.724797
# 129  3302403           Macaé (RJ)  2018  54.698516
#
# [130 rows x 4 columns]

# %%
## Salário / Qtd. Pessoas Assalariadas
fig_dims = (12, 7)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_salario_assalariado_melted , x="Year", y="Salarios", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Média Salarial')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Salário por Qtd. Pessoas Assalariadas')
# Exportar figura com legenda externa
plt.savefig('/content/top10_pessoas_assalariadas.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
## Casamentos
fig_dims = (8, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(data=top10_casamentos_melted, x="Year", y="Casamentos", hue="Municípios", style = 'Municípios', ax = ax, markers = True)

# Retirar marca de notação científica
ax.ticklabel_format(style='plain', axis = 'y')
# Formatar com 'M' e 'K' de milhões e mil, respectivamente
ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
# Rotacionar os anos 45 graus
plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
# Posição da legenda na direita e fora da figura
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylabel('Nro. Casamentos')
plt.xlabel('Ano')
plt.title('Dez Maiores Municípios - Nro. de Casamentos por Ano')
# Exportar figura com legenda externa
plt.savefig('/content/top10_casamentos.pdf', bbox_extra_artists = (lgd,), bbox_inches='tight')
plt.show()

# %%
## Salário
plt.figure(figsize=(18,7)) 
showfliers = False
for i in range(0,2):
  if i == 1:
    showfliers = True
  plt.subplot(1,2,i+1)
  ax = sns.boxplot(data=salarios_melted, x="Year", y="Salarios", palette = 'Set3', showfliers=showfliers) #hue="Municípios", style = 'Municípios', ax = ax, markers = True
  #ax.legend()
  # Retirar marca de notação científica
  ax.ticklabel_format(style='plain', axis = 'y')
  # Formatar com 'M' e 'K' de milhões e mil, respectivamente
  ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
  # Rotacionar os anos 45 graus
  plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
  # Posição da legenda na direita e fora da figura
  #lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
  plt.ylabel('Salário')
  plt.xlabel('Ano')
  if i == 1:
    plt.title('Salário por Ano (Sem Outliers)')
  else:
    plt.title('Salário por Ano (Com Outliers)')
  #ax.set_ylim(salarios_melted['Salarios'].min(),salarios_melted['Salarios'].max())
  # Exportar figura com legenda externa
  plt.savefig('/content/boxplot_salarios.pdf' ) #bbox_extra_artists = (lgd,), bbox_inches='tight'
  #plt.show()

# %%
populacao_melted
# Out:
#          Código                  Municípios  Year  Populacao
# 0       1100015  Alta Floresta D'Oeste (RO)  1991    31980.0
# 1       1100023              Ariquemes (RO)  1991    83684.0
# 2       1100031                 Cabixi (RO)  1991     8174.0
# 3       1100049                 Cacoal (RO)  1991    78934.0
# 4       1100056             Cerejeiras (RO)  1991    21608.0
# ...         ...                         ...   ...        ...
# 122535  5222005             Vianópolis (GO)  2019    13863.0
# 122536  5222054         Vicentinópolis (GO)  2019     8743.0
# 122537  5222203               Vila Boa (GO)  2019     6171.0
# 122538  5222302          Vila Propício (GO)  2019     5821.0
# 122539  5300108               Brasília (DF)  2019  3015268.0
#
# [122540 rows x 4 columns]

# %%
## População
plt.figure(figsize=(18,7)) 
showfliers = False
for i in range(0,2):
  if i == 1:
    showfliers = True
  plt.subplot(1,2,i+1)
  ax = sns.boxplot(data=populacao_melted, x="Year", y="Populacao", palette = 'Set3', showfliers=showfliers)

  # Retirar marca de notação científica
  ax.ticklabel_format(style='plain', axis = 'y')
  # Formatar com 'M' e 'K' de milhões e mil, respectivamente
  ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
  # Rotacionar os anos 45 graus
  plt.xticks(rotation=45) #ax.set_xticklabels(rotation = 30)
  # Posição da legenda na direita e fora da figura
  #lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
  plt.ylabel('População')
  plt.xlabel('Ano')
  if i == 1:
    plt.title('População por Ano (Sem Outliers)')
  else:
    plt.title('População por Ano (Com Outliers)')
  # Exportar figura com legenda externa
  plt.savefig('/content/boxplot_populacao.pdf') #,bbox_extra_artists = (lgd,), bbox_inches='tight'
  #plt.show()

# %%
## PIB
plt.figure(figsize=(18,7)) 
showfliers = False
for i in range(0,2):
  if i == 1:
    showfliers = True
  plt.subplot(1,2,i+1)
  ax = sns.boxplot(data=pib_melted, x="Year", y="Pib", palette = 'Set3', showfliers=showfliers)
  # Posição da legenda na direita e fora da figura
  #lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

  ax.ticklabel_format(style='plain', axis = 'y')
  ax.yaxis.set_major_formatter(tick.FuncFormatter(numeric_format_float))
  plt.xticks(rotation=45)
  plt.ylabel('PIB')
  plt.xlabel('Ano')
  if i == 1:
    plt.title('PIB por Ano (Sem Outliers)')
  else:
    plt.title('PIB por Ano (Com Outliers)')
# Exportar figura com legenda externa
  plt.savefig('/content/boxplot_pib.pdf')#, bbox_extra_artists = (lgd,), bbox_inches='tight')

# %%
top10_idhm_melted
# Out:
#      Código          Municípios       Year   IDHM
# 0   3548807  São Caetano do Sul  IDHM 1991  0.697
# 1   3500600  Águas de São Pedro  IDHM 1991  0.634
# 2   4205407       Florianópolis  IDHM 1991  0.681
# 3   3205309             Vitória  IDHM 1991  0.644
# 4   4202008  Balneário Camboriú  IDHM 1991  0.630
# 5   3548500              Santos  IDHM 1991  0.689
# 6   3303302             Niterói  IDHM 1991  0.681
# 7   4209003             Joaçaba  IDHM 1991  0.635
# 8   5300108            Brasília  IDHM 1991  0.616
# 9   4106902            Curitiba  IDHM 1991  0.640
# 10  3548807  São Caetano do Sul  IDHM 2000  0.820
# 11  3500600  Águas de São Pedro  IDHM 2000  0.791
# 12  4205407       Florianópolis  IDHM 2000  0.766
# 13  3205309             Vitória  IDHM 2000  0.759
# 14  4202008  Balneário Camboriú  IDHM 2000  0.777
# 15  3548500              Santos  IDHM 2000  0.785
# 16  3303302             Niterói  IDHM 2000  0.771
# 17  4209003             Joaçaba  IDHM 2000  0.741
# ...

# %%
from matplotlib.ticker import FixedFormatter
# IDHM
filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
plt.figure(figsize=(24,20)) 
top10_idhm_melted['Year'] = top10_idhm_melted['Year'].astype('object')
df_iter = [top10_idhm_melted, top10_idhm_renda_melted, top10_idhm_longevidade_melted, top10_idhm_educacao_melted]
for iter in df_iter:
  iter['Year'] = iter['Year'].astype('object')
#xi = list(range(len(x)))
#
ylabel_list = ['IDHM', 'IDHM Renda', 'IDHM Longevidade', 'IDHM Educação']
for i in range(0, 4):
    plt.subplot(2,2,i+1)
    ax = sns.lineplot(data=df_iter[i], x="Year", y=df_iter[i].columns[-1], hue="Municípios", style = 'Municípios', markers = True)
    xi = list(range(len([1999.5, 1995, 1997.5, 2000, 2002.5, 2005, 2007.5, 2010])))
    #formatter = ('1991', '2000', '2010')
    ##formatter.insert(0, 0)
    #x_formatter = FixedFormatter(formatter)
    ax.yaxis.set_major_formatter(tick.FuncFormatter(percent_format_float))
    #ax.xaxis.set_major_formatter(x_formatter)
    #x = ['1991', '', '', '', '2000', '', '', '', '2010']
    #plt.xticks([1991, 2000, 2009])
    plt.xlabel('Ano')
    plt.ylabel(ylabel_list[i])
    plt.title('Dez Maiores Municípios - '+ylabel_list[i]+' por Ano')
    #plt.show()
    plt.savefig('/content/top10_idhm.pdf')#, bbox_extra_artists = (lgd,), bbox_inches='tight')

# %%
from matplotlib.ticker import FixedFormatter
# IDHM
#filled_markers = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
plt.figure(figsize=(25,18)) 
idhm_melted['Year'] = idhm_melted['Year'].astype('object')
df_iter = [idhm_melted, idhm_renda_melted, idhm_longevidade_melted, idhm_educacao_melted]
for iter in df_iter:
  iter['Year'] = iter['Year'].astype('object')
#xi = list(range(len(x)))
#
ylabel_list = ['IDHM', 'IDHM Renda', 'IDHM Longevidade', 'IDHM Educação']
for i in range(0, 4):
    plt.subplot(2,2,i+1)
    ax = sns.boxplot(data=df_iter[i], x="Year", y=df_iter[i].columns[-1], palette = 'Set3', showfliers=False) #hue="Municípios", style = 'Municípios', markers = True
    xi = list(range(len([1999.5, 1995, 1997.5, 2000, 2002.5, 2005, 2007.5, 2010])))
    #formatter = ('1991', '2000', '2010')
    ##formatter.insert(0, 0)
    ax.yaxis.set_major_formatter(tick.FuncFormatter(percent_format_float))
    #x_formatter = FixedFormatter(formatter)
    #ax.xaxis.set_major_formatter(x_formatter)
    #x = ['1991', '', '', '', '2000', '', '', '', '2010']
    #plt.xticks(xi, x)
    plt.xlabel('Ano')
    plt.ylabel(ylabel_list[i])
    plt.title(ylabel_list[i]+' por Ano')
    #plt.show()
    plt.savefig('/content/boxplot_idhm.pdf')#, bbox_extra_artists = (lgd,), bbox_inches='tight')

# %% [markdown]
# # Engenharia de Dados

# %%
#!pip install gspread
#!pip install oauth2client

# %%
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials
import pandas as pd
import numpy as np

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())
ibge_data_total = gc.open('IBGE Data')

# %%
##IDHM
index = 0
df_aux = ibge_data_total.get_worksheet(index) 
data = df_aux.get_all_values()
headers = data.pop(0)
df_idhm = pd.DataFrame(data, columns=headers)
df_idhm = df_idhm.replace('...', np.nan)
df_idhm = df_idhm.set_index('Código')
for i in df_idhm.columns:
  if ('20' in i) or ('19' in i):
    df_idhm[i] = df_idhm[i].astype('float64')
df_idhm.head(3)
# Out:
#                   Municípios  IDHM 1991  ...  IDHM Educação 2000  IDHM Educação 2010
# Código                                   ...
# 76                    Brasil      0.493  ...               0.456               0.637
# 5200050      Abadia de Goiás      0.408  ...               0.386               0.622
# 3100104  Abadia dos Dourados      0.449  ...               0.387               0.563
#
# [3 rows x 13 columns]

# %%
## Unidade Empresarias
index = 1
df_aux = ibge_data_total.get_worksheet(index) 
data = df_aux.get_all_values()[2:]
headers = data.pop(0)
df_empresas_old = pd.DataFrame(data[:], columns=headers)
df_empresas_old = df_empresas_old.replace('...', np.nan)
df_empresas_old = df_empresas_old.set_index('Código')
df_empresas_old.head(3)
for i in df_empresas_old.columns:
  if ('20' in i) or ('19' in i):
    df_empresas_old[i] = df_empresas_old[i].astype('float64')
df_empresas_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5564 entries, 1100015 to 5300108
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Municípios  5564 non-null   object
#  1   1996        5024 non-null   float64
#  2   1997        5493 non-null   float64
#  3   1998        5502 non-null   float64
#  4   1999        5504 non-null   float64
#  5   2000        5505 non-null   float64
#  6   2001        5560 non-null   float64
#  7   2002        5560 non-null   float64
#  8   2003        5560 non-null   float64
#  9   2004        5560 non-null   float64
#  10  2005        5564 non-null   float64
#  11  2006        5564 non-null   float64
# dtypes: float64(11), object(1)
# memory usage: 565.1+ KB

# %%
## Nro Casamentos
index = 2
df_aux = ibge_data_total.get_worksheet(index) 
data = df_aux.get_all_values()[2:]
headers = data.pop(0)
df_casamentos = pd.DataFrame(data[:], columns=headers)
df_casamentos = df_casamentos.replace('...', np.nan)
df_casamentos = df_casamentos.set_index('Código')
for i in df_casamentos.columns:
  if ('20' in i) or ('19' in i):
    df_casamentos[i] = df_casamentos[i].astype('float64')
df_casamentos.head(3)
# Out:
#                          Municípios   2003   2004  ...    2016   2017   2018
# Código                                             ...
# 1100015  Alta Floresta D'Oeste (RO)  124.0  129.0  ...   175.0  171.0  192.0
# 1100023              Ariquemes (RO)  368.0  449.0  ...  1007.0  980.0  665.0
# 1100031                 Cabixi (RO)   45.0   34.0  ...    42.0   50.0   45.0
#
# [3 rows x 17 columns]

# %%
#Variável - Salários e outras remunerações (Mil Reais)														
index = 4
df_aux = ibge_data_total.get_worksheet(index) 
data = df_aux.get_all_values()[2:]
headers = data.pop(0)
df_salarios = pd.DataFrame(data[:], columns=headers)
df_salarios = df_salarios.replace('...', np.nan)
df_salarios = df_salarios.replace('X', np.nan)
df_salarios = df_salarios.replace('-', np.nan)
df_salarios = df_salarios.set_index('Código')
for i in df_salarios.columns:
  if ('20' in i) or ('19' in i):
    df_salarios[i] = df_salarios[i].astype('float64')
df_salarios.head(3)
# Out:
#                          Municípios     2006  ...      2017      2018
# Código                                        ...
# 1100015  Alta Floresta D'Oeste (RO)  13201.0  ...   54002.0   52732.0
# 1100023              Ariquemes (RO)  96098.0  ...  377716.0  386576.0
# 1100031                 Cabixi (RO)   2321.0  ...   10315.0   10209.0
#
# [3 rows x 14 columns]

# %%
df_salarios[df_salarios['2006'] == 'X']
# Out:
# Empty DataFrame
# Columns: [Municípios, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
# Index: []

# %%
## População  
index = 5
df_aux = ibge_data_total.get_worksheet(index) 
data = df_aux.get_all_values()[:]
headers = data.pop(0)
df_populacao = pd.DataFrame(data[:], columns=headers)
df_populacao = df_populacao.replace('...', np.nan)
df_populacao = df_populacao.replace('', np.nan)
df_populacao = df_populacao.set_index('Código')
for i in df_populacao.columns:
  if ('20' in i) or ('19' in i):
    df_populacao[i] = df_populacao[i].astype('float64')
df_populacao.head(3)
# Out:
#                          Municípios     1991  ...      2018      2019
# Código                                        ...
# 1100015  Alta Floresta D'Oeste (RO)  31980.0  ...   23167.0   22945.0
# 1100023              Ariquemes (RO)  83684.0  ...  106168.0  107863.0
# 1100031                 Cabixi (RO)   8174.0  ...    5438.0    5312.0
#
# [3 rows x 23 columns]

# %%
## PIB
index = 6
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()
headers = data.pop(0)
df_pib = pd.DataFrame(data, columns=headers)
df_pib = df_pib.replace('...', np.nan)
df_pib = df_pib.set_index('Código')
for i in df_pib.columns:
  if ('20' in i) or ('19' in i):
    df_pib[i] = df_pib[i].astype('float64')
df_pib.head(3)
# Out:
#                     Municípios       2002  ...        2016        2017
# Código                                     ...
# 1100015  Alta Floresta D'Oeste  111291.00  ...   478216.98   498864.19
# 1100023              Ariquemes  449592.82  ...  2184346.10  2296073.71
# 1100031                 Cabixi   31767.52  ...   133342.25   138893.55
#
# [3 rows x 17 columns]

# %%
df_pib.head()
# Out:
#                     Municípios       2002  ...        2016        2017
# Código                                     ...
# 1100015  Alta Floresta D'Oeste  111291.00  ...   478216.98   498864.19
# 1100023              Ariquemes  449592.82  ...  2184346.10  2296073.71
# 1100031                 Cabixi   31767.52  ...   133342.25   138893.55
# 1100049                 Cacoal  474443.10  ...  1947282.54  2127523.25
# 1100056             Cerejeiras   79173.61  ...   408193.83   448524.17
#
# [5 rows x 17 columns]

# %%
## Unidades Empresariais - Novo
index = 10
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[2:]
headers = data.pop(0)
df_empresas = pd.DataFrame(data, columns=headers)
df_empresas = df_empresas.replace('...', np.nan)
df_empresas = df_empresas.set_index('Código')
for i in df_empresas.columns:
  if ('20' in i) or ('19' in i):
    df_empresas[i] = df_empresas[i].astype('float64')
df_empresas.head(3)
# Out:
#                          Municípios    2006    2007  ...    2016    2017    2018
# Código                                               ...
# 1100015  Alta Floresta D'Oeste (RO)   453.0   364.0  ...   508.0   549.0   478.0
# 1100023              Ariquemes (RO)  1614.0  1596.0  ...  2221.0  2233.0  2252.0
# 1100031                 Cabixi (RO)    63.0    81.0  ...    60.0    65.0    66.0
#
# [3 rows x 14 columns]

# %%
## Pessoas Empregadas
index = 11
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[2:]
headers = data.pop(0)
df_empregadas = pd.DataFrame(data, columns=headers)
df_empregadas = df_empregadas.replace('...', np.nan)
df_empregadas = df_empregadas.replace('X', np.nan)
df_empregadas = df_empregadas.replace('-', np.nan)
df_empregadas = df_empregadas.replace('', np.nan)
df_empregadas = df_empregadas.set_index('Código')
for i in df_empregadas.columns:
  if ('20' in i) or ('19' in i):
    df_empregadas[i] = df_empregadas[i].astype('float64')
df_empregadas.head(3)
# Out:
#                          Municípios     2006  ...     2017     2018
# Código                                        ...
# 1100015  Alta Floresta D'Oeste (RO)   2138.0  ...   3255.0   3156.0
# 1100023              Ariquemes (RO)  12490.0  ...  18876.0  19002.0
# 1100031                 Cabixi (RO)    362.0  ...    582.0    533.0
#
# [3 rows x 14 columns]

# %%
## Pessoas Assalariadas
index = 12
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[2:]
headers = data.pop(0)
df_assalariadas = pd.DataFrame(data, columns=headers)
df_assalariadas = df_assalariadas.replace('...', np.nan)
df_assalariadas = df_assalariadas.replace('X', np.nan)
df_assalariadas = df_assalariadas.replace('-', np.nan)
df_assalariadas = df_assalariadas.replace('', np.nan)
df_assalariadas = df_assalariadas.set_index('Código')
for i in df_assalariadas.columns:
  if ('20' in i) or ('19' in i):
    df_assalariadas[i] = df_assalariadas[i].astype('float64')
df_assalariadas.head(3)
# Out:
#                          Municípios     2006  ...     2017     2018
# Código                                        ...
# 1100015  Alta Floresta D'Oeste (RO)   1673.0  ...   2511.0   2487.0
# 1100023              Ariquemes (RO)  10244.0  ...  15641.0  15678.0
# 1100031                 Cabixi (RO)    293.0  ...    490.0    464.0
#
# [3 rows x 14 columns]

# %%
## Produto Interno Bruto a preços correntes (Mil Reais)
index = 13
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_correntes_1 = pd.DataFrame(data, columns=headers)
df_pib_correntes_1 = df_pib_correntes_1.replace('...', np.nan)
df_pib_correntes_1 = df_pib_correntes_1.set_index('Código')
for i in df_pib_correntes_1.columns:
  if ('20' in i) or ('19' in i):
    df_pib_correntes_1[i] = df_pib_correntes_1[i].astype('float64')
df_pib_correntes_1.head(3)
# Out:
#                          Municípios          2002  ...          2016          2017
# Código                                             ...
# 1                            Brasil  1.488787e+09  ...  6.269328e+09  6.583319e+09
# 1100015  Alta Floresta D'Oeste (RO)  1.112910e+05  ...  4.782170e+05  4.988640e+05
# 1100023              Ariquemes (RO)  4.495930e+05  ...  2.184346e+06  2.296074e+06
#
# [3 rows x 17 columns]

# %%
#Variável - Valor adicionado bruto a preços correntes da agropecuária (Mil Reais)
index = 14
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_agropecuaria = pd.DataFrame(data, columns=headers)
df_pib_agropecuaria = df_pib_agropecuaria.replace('...', np.nan)
df_pib_agropecuaria = df_pib_agropecuaria.set_index('Código')
for i in df_pib_agropecuaria.columns:
  if ('20' in i) or ('19' in i):
    df_pib_agropecuaria[i] = df_pib_agropecuaria[i].astype('float64')
df_pib_agropecuaria.head(3)
# Out:
#                          Municípios        2002  ...         2016         2017
# Código                                           ...
# 1                            Brasil  81515199.0  ...  306655000.0  302971000.0
# 1100015  Alta Floresta D'Oeste (RO)     27013.0  ...     166143.0     169623.0
# 1100023              Ariquemes (RO)     28590.0  ...     145069.0     165217.0
#
# [3 rows x 17 columns]

# %%
#Variável - Valor adicionado bruto a preços correntes da indústria (Mil Reais)
index = 15
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_industria = pd.DataFrame(data, columns=headers)
df_pib_industria = df_pib_industria.replace('...', np.nan)
df_pib_industria = df_pib_industria.set_index('Código')
for i in df_pib_industria.columns:
  if ('20' in i) or ('19' in i):
    df_pib_industria[i] = df_pib_industria[i].astype('float64')
df_pib_industria.head(3)
# Out:
#                          Municípios         2002  ...          2016          2017
# Código                                            ...
# 1                            Brasil  334907570.0  ...  1.150720e+09  1.196931e+09
# 1100015  Alta Floresta D'Oeste (RO)       9377.0  ...  3.159800e+04  2.780500e+04
# 1100023              Ariquemes (RO)      99923.0  ...  3.542870e+05  3.303190e+05
#
# [3 rows x 17 columns]

# %%
#Variável - Impostos, líquidos de subsídios, sobre produtos a preços correntes (Mil Reais)
index = 16
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_produtos = pd.DataFrame(data, columns=headers)
df_pib_produtos = df_pib_produtos.replace('...', np.nan)
df_pib_produtos = df_pib_produtos.set_index('Código')
for i in df_pib_produtos.columns:
  if ('20' in i) or ('19' in i):
    df_pib_produtos[i] = df_pib_produtos[i].astype('float64')
df_pib_produtos.head(3)
# Out:
#                          Municípios         2002  ...         2016         2017
# Código                                            ...
# 1                            Brasil  218572609.0  ...  849506000.0  913553000.0
# 1100015  Alta Floresta D'Oeste (RO)       7549.0  ...      23202.0      28793.0
# 1100023              Ariquemes (RO)      42666.0  ...     216460.0     232012.0
#
# [3 rows x 17 columns]

# %%
#Variável - Valor adicionado bruto a preços correntes total (Mil Reais)
index = 17
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_correntes_2 = pd.DataFrame(data, columns=headers)
df_pib_correntes_2 = df_pib_correntes_2.replace('...', np.nan)
df_pib_correntes_2 = df_pib_correntes_2.set_index('Código')
for i in df_pib_correntes_2.columns:
  if ('20' in i) or ('19' in i):
    df_pib_correntes_2[i] = df_pib_correntes_2[i].astype('float64')
df_pib_correntes_2.head(3)
# Out:
#                          Municípios          2002  ...          2016          2017
# Código                                             ...
# 1                            Brasil  1.270215e+09  ...  5.419822e+09  5.669766e+09
# 1100015  Alta Floresta D'Oeste (RO)  1.037420e+05  ...  4.550140e+05  4.700720e+05
# 1100023              Ariquemes (RO)  4.069270e+05  ...  1.967886e+06  2.064062e+06
#
# [3 rows x 17 columns]

# %%
#Variável - Valor adicionado bruto a preços correntes dos serviços, exclusive administração, defesa, educação e saúde públicas e seguridade social (Mil Reais)
index = 18
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_sociedade_1 = pd.DataFrame(data, columns=headers)
df_pib_sociedade_1 = df_pib_sociedade_1.replace('...', np.nan)
df_pib_sociedade_1 = df_pib_sociedade_1.set_index('Código')
for i in df_pib_sociedade_1.columns:
  if ('20' in i) or ('19' in i):
    df_pib_sociedade_1[i] = df_pib_sociedade_1[i].astype('float64')
df_pib_sociedade_1.head(3)
# Out:
#                          Municípios         2002  ...          2016          2017
# Código                                            ...
# 1                            Brasil  644403214.0  ...  3.017326e+09  3.168889e+09
# 1100015  Alta Floresta D'Oeste (RO)      24651.0  ...  1.145410e+05  1.177170e+05
# 1100023              Ariquemes (RO)     161852.0  ...  8.795550e+05  9.339350e+05
#
# [3 rows x 17 columns]

# %%
#Variável - Valor adicionado bruto a preços correntes da administração, defesa, educação e saúde públicas e seguridade social (Mil Reais)
index = 19
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[3:]
headers = data.pop(0)
df_pib_sociedade_2 = pd.DataFrame(data, columns=headers)
df_pib_sociedade_2 = df_pib_sociedade_2.replace('...', np.nan)
df_pib_sociedade_2 = df_pib_sociedade_2.set_index('Código')
for i in df_pib_sociedade_2.columns:
  if ('20' in i) or ('19' in i):
    df_pib_sociedade_2[i] = df_pib_sociedade_2[i].astype('float64')
df_pib_sociedade_2.head(3)
# Out:
#                          Municípios         2002  ...         2016          2017
# Código                                            ...
# 1                            Brasil  209388684.0  ...  945121000.0  1.000975e+09
# 1100015  Alta Floresta D'Oeste (RO)      42701.0  ...     142733.0  1.549260e+05
# 1100023              Ariquemes (RO)     116562.0  ...     588975.0  6.345910e+05
#
# [3 rows x 17 columns]

# %%
# LatLong + Código UF
index = 20
name_worksheet_aux = ibge_data_total.worksheets()[index].title
worksheet_aux = ibge_data_total.get_worksheet(index) 
data = worksheet_aux.get_all_values()[:]
headers = data.pop(0)
df_latlong = pd.DataFrame(data, columns=headers)
df_latlong = df_latlong.set_index('Código')
df_latlong.head(3)
df_latlong['Latitude'] = df_latlong['Latitude'].astype('float64')
df_latlong['Longitude'] = df_latlong['Longitude'].astype('float64')

# %% [markdown]
# # Engenharia de Dados - Melted

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns

def numeric_format_float(tick_val, pos):
    tick_val = tick_val.round(0)
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.0f} M'.format(val)
    elif tick_val > 1000:
        val = int(tick_val) / 1000
        return '{:.0f} k'.format(val)
    else:
        return '{:.0f}'.format(tick_val)

def percent_format_float(tick_val, pos):
    if tick_val > 0:
        return str(round(float(tick_val) * 100,0))+' %'
    else:
        return '0 %'

# %%
## Empresas_old Melted
empresas_old = df_empresas_old.reset_index()
empresas_old_melted = pd.melt(empresas_old, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empresas_old')
empresas_old_sorted = empresas_old.sort_values(by = df_empresas_old.columns[-1], ascending = False)
# Top 10 Empresas_old Melted
top10_empresas_old_melted = pd.melt(empresas_old_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empresas_old')

## Casamentos Melted
casamentos = df_casamentos.reset_index()
casamentos_melted = pd.melt(casamentos, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Casamentos')
casamentos_sorted = casamentos.sort_values(by = df_casamentos.columns[-1], ascending = False)
# Top 10 Casamentos Melted
top10_casamentos_melted = pd.melt(casamentos_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Casamentos')

## Salarios Melted
salarios = df_salarios.reset_index()
salarios_melted = pd.melt(salarios, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salarios')
salarios_sorted = salarios.sort_values(by = df_salarios.columns[-1], ascending = False)
# Top 10 Salarios Melted
top10_salarios_melted = pd.melt(salarios_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salarios')

## Populacao Melted
populacao = df_populacao.reset_index()
populacao_melted = pd.melt(populacao, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Populacao')
populacao_sorted = populacao.sort_values(by = df_populacao.columns[-1], ascending = False)
# Top 10 Populacao Melted
top10_populacao_melted = pd.melt(populacao_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Populacao')

## Pib Melted
pib = df_pib.reset_index()
pib_melted = pd.melt(pib, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib')
pib_sorted = pib.sort_values(by = df_pib.columns[-1], ascending = False)
# Top 10 Pib Melted
top10_pib_melted = pd.melt(pib_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib')

## Empresas Melted
empresas = df_empresas.reset_index()
empresas_melted = pd.melt(empresas, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empresas')
empresas_sorted = empresas.sort_values(by = df_empresas.columns[-1], ascending = False)
# Top 10 Empresas Melted
top10_empresas_melted = pd.melt(empresas_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empresas')

## Empregadas Melted
empregadas = df_empregadas.reset_index()
empregadas_melted = pd.melt(empregadas, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empregadas')
empregadas_sorted = empregadas.sort_values(by = df_empregadas.columns[-1], ascending = False)
# Top 10 Empregadas Melted
top10_empregadas_melted = pd.melt(empregadas_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Empregadas')

## Assalariadas Melted
assalariadas = df_assalariadas.reset_index()
assalariadas_melted = pd.melt(assalariadas, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Assalariadas')
assalariadas_sorted = assalariadas.sort_values(by = df_assalariadas.columns[-1], ascending = False)
# Top 10 Assalariadas Melted
top10_assalariadas_melted = pd.melt(assalariadas_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Assalariadas')

## Pib_correntes_1 Melted
pib_correntes_1 = df_pib_correntes_1.reset_index()
pib_correntes_1_melted = pd.melt(pib_correntes_1, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_correntes_1')
pib_correntes_1_sorted = pib_correntes_1.sort_values(by = df_pib_correntes_1.columns[-1], ascending = False)
# Top 10 Pib_correntes_1 Melted
top10_pib_correntes_1_melted = pd.melt(pib_correntes_1_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_correntes_1')

## Pib_agropecuaria Melted
pib_agropecuaria = df_pib_agropecuaria.reset_index()
pib_agropecuaria_melted = pd.melt(pib_agropecuaria, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_agropecuaria')
pib_agropecuaria_sorted = pib_agropecuaria.sort_values(by = df_pib_agropecuaria.columns[-1], ascending = False)
# Top 10 Pib_agropecuaria Melted
top10_pib_agropecuaria_melted = pd.melt(pib_agropecuaria_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_agropecuaria')

## Pib_industria Melted
pib_industria = df_pib_industria.reset_index()
pib_industria_melted = pd.melt(pib_industria, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_industria')
pib_industria_sorted = pib_industria.sort_values(by = df_pib_industria.columns[-1], ascending = False)
# Top 10 Pib_industria Melted
top10_pib_industria_melted = pd.melt(pib_industria_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_industria')

## Pib_produtos Melted
pib_produtos = df_pib_produtos.reset_index()
pib_produtos_melted = pd.melt(pib_produtos, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_produtos')
pib_produtos_sorted = pib_produtos.sort_values(by = df_pib_produtos.columns[-1], ascending = False)
# Top 10 Pib_produtos Melted
top10_pib_produtos_melted = pd.melt(pib_produtos_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_produtos')

## Pib_correntes_2 Melted
pib_correntes_2 = df_pib_correntes_2.reset_index()
pib_correntes_2_melted = pd.melt(pib_correntes_2, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_correntes_2')
pib_correntes_2_sorted = pib_correntes_2.sort_values(by = df_pib_correntes_2.columns[-1], ascending = False)
# Top 10 Pib_correntes_2 Melted
top10_pib_correntes_2_melted = pd.melt(pib_correntes_2_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_correntes_2')

## Pib_sociedade_1 Melted
pib_sociedade_1 = df_pib_sociedade_1.reset_index()
pib_sociedade_1_melted = pd.melt(pib_sociedade_1, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_sociedade_1')
pib_sociedade_1_sorted = pib_sociedade_1.sort_values(by = df_pib_sociedade_1.columns[-1], ascending = False)
# Top 10 Pib_sociedade_1 Melted
top10_pib_sociedade_1_melted = pd.melt(pib_sociedade_1_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_sociedade_1')

## Pib_sociedade_2 Melted
pib_sociedade_2 = df_pib_sociedade_2.reset_index()
pib_sociedade_2_melted = pd.melt(pib_sociedade_2, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_sociedade_2')
pib_sociedade_2_sorted = pib_sociedade_2.sort_values(by = df_pib_sociedade_2.columns[-1], ascending = False)
# Top 10 Pib_sociedade_2 Melted
top10_pib_sociedade_2_melted = pd.melt(pib_sociedade_2_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Pib_sociedade_2')

## Latlong Melted
latlong = df_latlong.reset_index()
latlong_melted = pd.melt(latlong, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Latlong')
latlong_sorted = latlong.sort_values(by = df_latlong.columns[-1], ascending = False)
# Top 10 Latlong Melted
top10_latlong_melted = pd.melt(latlong_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Latlong')

## Salarios / Assalariados
salario_assalariado = salarios.copy()
for year in range(2006, 2019):
  salario_assalariado[str(year)] = salarios[str(year)] / assalariadas[str(year)]
salario_assalariado_melted = pd.melt(salario_assalariado, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salário por Assalariado')

salario_assalariado_sorted = salario_assalariado.sort_values(by = salario_assalariado.columns[-1], ascending = False)
# Top 10 Salarios Melted
salario_assalariado_melted = pd.melt(salario_assalariado_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salarios')

# %%
## Idhm Melted

idhm = df_idhm.reset_index()
idhm_t = idhm[['Código', 'Municípios','IDHM 1991','IDHM 2000','IDHM 2010']]
idhm_renda = idhm[['Código', 'Municípios','IDHM Renda 1991','IDHM Renda 2000','IDHM Renda 2010']]
idhm_longevidade = idhm[['Código', 'Municípios','IDHM Longevidade 1991','IDHM Longevidade 2000','IDHM Longevidade 2010']]
idhm_educacao = idhm[['Código', 'Municípios','IDHM Educação 1991','IDHM Educação 2000','IDHM Educação 2010']]

idhm = idhm_t.sort_values(by = idhm_t.columns[-1], ascending = False)
idhm_renda = idhm_renda.sort_values(by = idhm_renda.columns[-1], ascending = False)
idhm_longevidade = idhm_longevidade.sort_values(by = idhm_longevidade.columns[-1], ascending = False)
idhm_educacao = idhm_educacao.sort_values(by = idhm_educacao.columns[-1], ascending = False)

idhm_melted = pd.melt(idhm, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM')
idhm_renda_melted = pd.melt(idhm_renda, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Renda')
idhm_longevidade_melted = pd.melt(idhm_longevidade, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Longevidade')
idhm_educacao_melted = pd.melt(idhm_educacao, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Educacao')

top10_idhm = idhm_t.sort_values(by = idhm_t.columns[-1], ascending = False).head(10)
top10_idhm_renda = idhm_renda.sort_values(by = idhm_renda.columns[-1], ascending = False).head(10)
top10_idhm_longevidade = idhm_longevidade.sort_values(by = idhm_longevidade.columns[-1], ascending = False).head(10)
top10_idhm_educacao = idhm_educacao.sort_values(by = idhm_educacao.columns[-1], ascending = False).head(10)

top10_idhm_melted = pd.melt(top10_idhm, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM')
top10_idhm_renda_melted = pd.melt(top10_idhm_renda, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Renda')
top10_idhm_longevidade_melted = pd.melt(top10_idhm_longevidade, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Longevidade')
top10_idhm_educacao_melted = pd.melt(top10_idhm_educacao, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'IDHM_Educacao')

#idhm_melted = pd.melt(idhm, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Idhm')
#idhm_sorted = idhm.sort_values(by = df_idhm.columns[-1], ascending = False)
# Top 10 Idhm Melted
#top10_idhm_melted = pd.melt(idhm_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Idhm')

# %%
top10_idhm_melted['Year'] = top10_idhm_melted['Year'].str.extract('(\d+)').astype(int)
top10_idhm_renda_melted['Year'] = top10_idhm_renda_melted['Year'].str.extract('(\d+)').astype(int)
top10_idhm_longevidade_melted['Year'] = top10_idhm_longevidade_melted['Year'].str.extract('(\d+)').astype(int)
top10_idhm_educacao_melted['Year'] = top10_idhm_educacao_melted['Year'].str.extract('(\d+)').astype(int)

## Salarios / Assalariados
salario_assalariado = salarios.copy()
for year in range(2006, 2019):
  salario_assalariado[str(year)] = salarios[str(year)] / assalariadas[str(year)]
#salario_assalariado_melted = pd.melt(salario_assalariado, id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salário por Assalariado')

salario_assalariado_sorted = salario_assalariado.sort_values(by = salario_assalariado.columns[-1], ascending = False)
# Top 10 Salarios Melted
top10_salario_assalariado_melted = pd.melt(salario_assalariado_sorted.head(10), id_vars = ['Código', 'Municípios'], var_name= 'Year', value_name = 'Salarios')
top10_salario_assalariado_melted
# Out:
#       Código           Municípios  Year   Salarios
# 0    5300108        Brasília (DF)  2006  33.199119
# 1    3135407         Jeceaba (MG)  2006   7.670498
# 2    2803708       Macambira (SE)  2006   5.213483
# 3    4309605     Horizontina (RS)  2006  19.569207
# 4    4205407   Florianópolis (SC)  2006  21.444174
# ..       ...                  ...   ...        ...
# 125  2905701        Camaçari (BA)  2018  58.382160
# 126  3304110      Porto Real (RJ)  2018  57.687909
# 127  5103403          Cuiabá (MT)  2018  54.804166
# 128  3304557  Rio de Janeiro (RJ)  2018  54.724797
# 129  3302403           Macaé (RJ)  2018  54.698516
#
# [130 rows x 4 columns]

# %% [markdown]
# # Mapa Final'

# %%
#!npm install phantomjs-prebuilt
# Out:
# npm WARN deprecated phantomjs-prebuilt@2.1.16: this package is now deprecated
# npm WARN deprecated request@2.88.2: request has been deprecated, see https://github.com/request/request/issues/3142
# npm WARN deprecated har-validator@5.1.5: this library is no longer supported
#
# > phantomjs-prebuilt@2.1.16 install /content/node_modules/phantomjs-prebuilt
# > node install.js
#
# PhantomJS not found on PATH
# ...
# Saving to /tmp/phantomjs/phantomjs-2.1.1-linux-x86_64.tar.bz2
# Receiving...
#   [] 0%
# Received 22866K total.
# Extracting tar contents (via spawned process)
# Removing /content/node_modules/phantomjs-prebuilt/lib/phantom
# Copying extracted folder /tmp/phantomjs/phantomjs-2.1.1-linux-x86_64.tar.bz2-extract-1608225156238/phantomjs-2.1.1-linux-x86_64 -> /content/node_modules/phantomjs-prebuilt/lib/phantom
# Writing location.js file
# Done. Phantomjs binary available at /content/node_modules/phantomjs-prebuilt/lib/phantom/bin/phantomjs
# ...

# %%
#import os
#os.environ['BOKEH_PHANTOMJS_PATH'] = "/content/node_modules/phantomjs-prebuilt/lib/phantom/bin/phantomjs"

# %%
import folium
from folium import plugins
from sklearn import preprocessing
pib_melted_index = pib_melted.set_index('Código')
populacao_melted_index = populacao_melted.set_index('Código')
pib_pop_aux = pib_melted_index.merge(populacao_melted, on = ['Código', 'Year']) 
mask = ['Pib', 'Populacao']
x = pib_pop_aux[mask]
min_max_scaler = preprocessing.MinMaxScaler()
pib_pop_aux[mask] = min_max_scaler.fit_transform(x)
pib_pop_aux['Pib'] = pib_pop_aux['Pib'] * 100

# %%
pib_pop_aux_index = pib_pop_aux.set_index('Código')
pib_pop_latlong_melted = pib_pop_aux_index.merge(df_latlong, left_index = True, right_index = True)
pib_pop_latlong_melted.reset_index(inplace = True)

# %%
pib_pop_latlong_melted_1 = pib_pop_latlong_melted.pivot(index = 'Código', columns = 'Year')['Pib']

# %%
pib_pop_latlong_melted_2 = pib_pop_latlong_melted.pivot(index = 'Código', columns = 'Year')['Populacao']

# %%
#pib_pop_latlong_melted_1.merge(pib_pop_latlong_melted_2, on = 'Código')
#pib_pop_latlong_melted_1[pib_pop_latlong_melted_1.index == 1100015]
#pib_pop_latlong_melted_1.loc[1100015, :]
pib_pop_latlong_melted_1.reset_index(inplace = True)
pib_pop_latlong_melted_2.reset_index(inplace = True)
pib_pop_latlong_melted_final = pib_pop_latlong_melted_1.merge(pib_pop_latlong_melted_2, on = 'Código')
pib_pop_latlong_melted_final
# Out:
# Year   Código    2002_x    2003_x  ...    2015_y    2016_y    2017_y
# 0     1100015  0.018638  0.023204  ...  0.002046  0.002040  0.002035
# 1     1100023  0.067015  0.079891  ...  0.008557  0.008681  0.008801
# 2     1100031  0.007266  0.008584  ...  0.000459  0.000453  0.000448
# 3     1100049  0.070568  0.091731  ...  0.007139  0.007192  0.007245
# 4     1100056  0.014045  0.017021  ...  0.001419  0.001417  0.001415
# ...       ...       ...       ...  ...       ...       ...       ...
# 5565  5222005  0.015093  0.016541  ...  0.001045  0.001054  0.001063
# 5566  5222054  0.012213  0.015551  ...  0.000609  0.000618  0.000627
# 5567  5222203  0.004700  0.004984  ...  0.000387  0.000397  0.000407
# 5568  5222302  0.009310  0.009707  ...  0.000394  0.000399  0.000404
# 5569  5300108  7.710664  8.361869  ...  0.240707  0.245860  0.251000
#
# [5570 rows x 33 columns]

# %%
pib_pop_latlng_melted_final = pib_pop_latlong_melted_final.merge(df_latlong, left_on = 'Código', right_index = True)
pib_pop_latlng_melted_final
# Out:
#        Código    2002_x    2003_x  ...  Longitude  Capital  Código_UF
# 0     1100015  0.018638  0.023204  ...   -61.9953        0         11
# 1     1100023  0.067015  0.079891  ...   -63.0325        0         11
# 2     1100031  0.007266  0.008584  ...   -60.5520        0         11
# 3     1100049  0.070568  0.091731  ...   -61.4562        0         11
# 4     1100056  0.014045  0.017021  ...   -60.8168        0         11
# ...       ...       ...       ...  ...        ...      ...        ...
# 5565  5222005  0.015093  0.016541  ...   -48.5159        0         52
# 5566  5222054  0.012213  0.015551  ...   -49.8047        0         52
# 5567  5222203  0.004700  0.004984  ...   -47.0520        0         52
# 5568  5222302  0.009310  0.009707  ...   -48.8819        0         52
# 5569  5300108  7.710664  8.361869  ...   -47.9297        1         53
#
# [5570 rows x 38 columns]

# %%
import folium
import json
import requests
import selenium.webdriver

def color_producer(elevation):
    if elevation < 0.3:
        return 'green'
    elif 0.3 <= elevation < 0.9:
        return 'orange'
    else:
        return 'red'

country = 'Brazil'
r = requests.get('https://raw.github.com/python-visualization/folium/master/examples/data/world-countries.json')
country_geo = r.json()
for i in country_geo['features']:
    if i['properties']['name'] == 'Brazil':
        country = i
        break
cima = [-5.484973187334286, -55.44591693017724]
baixo = [-29.420639663260822, -50.216424967670484]

#year
for year in [2002,2017]:
    m = folium.Map(cima,zoom_start=4.5)
    for lat,lon,size, color in zip(pib_pop_latlng_melted_final['Latitude'],pib_pop_latlng_melted_final['Longitude'],pib_pop_latlng_melted_final[str(year)+'_x'], pib_pop_latlng_melted_final[str(year)+'_y']):
        folium.CircleMarker([lat, lon],
                                #popup=area,
                                radius=size,
                                color=color_producer(color),
                                fill=True,
                                fill_opacity=0.7
                                #fill_color=color_producer(color)
                              ).add_to(m)


    folium.GeoJson(country,name='brazil').add_to(m)
    m.save('/content/Map/'+str(year)+'brazil.html')

    driver = selenium.webdriver.PhantomJS(executable_path = '/content/node_modules/phantomjs-prebuilt/lib/phantom/bin/phantomjs')
    driver.set_window_size(4000, 3000)  # choose a resolution
    driver.get('/content/Map/'+str(year)+'brazil.html')
    driver.save_screenshot('/content/Png/'+str(year)+'brazil.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
